# %%
from flask import Flask, request, abort

from linebot import (
    LineBotApi, WebhookHandler
)
from linebot.exceptions import (
    InvalidSignatureError
)
from linebot.models import (
    MessageEvent, TextMessage, TextSendMessage, FlexSendMessage, FollowEvent
)

app = Flask(__name__)

line_bot_api = LineBotApi(
    'ckR0UoGld6smuqIIKZ14r7z086oroHuvwv7D/BroO8WHv3eAPwqfSu8jiKXZFtUDqzATRQdXMIV6Tm9fCifGfcslGkvhzs649fxD8XnSsvbDrgaJNW4j9uMEMHHlzDINkIOZxOfpPaWj1QGv9XKnwAdB04t89/1O/w1cDnyilFU=')
handler = WebhookHandler('47946a347d7631e904d3f94ec3a3e462')


@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(FollowEvent)
def handle_follow(event):
    line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text='歡迎使用測試機器人'))


@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    if event.message.text == '第一個動作':
        message = FlexSendMessage(alt_text='food', contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "url": "https://i.imgur.com/DbFtjvn.jpg"
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "sm",
        "contents": [
          {
            "type": "text",
            "text": "生春捲",
            "wrap": True,
            "weight": "bold",
            "size": "4xl",
            "style": "normal",
            "decoration": "none",
            "align": "center",
            "gravity": "center",
            "offsetTop": "12.5%"
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "spacing": "none",
        "contents": [
          {
            "type": "button",
            "style": "primary",
            "action": {
              "type": "message",
              "label": "查看介紹",
              "text": "生春捲介紹"
            },
            "height": "md"
          }
        ],
        "margin": "none"
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "url": "https://i.imgur.com/u03N3AU.jpg"
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "sm",
        "contents": [
          {
            "type": "text",
            "text": "法式麵包",
            "wrap": True,
            "weight": "bold",
            "size": "4xl",
            "style": "normal",
            "decoration": "none",
            "align": "center",
            "gravity": "center",
            "offsetTop": "12.5%"
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "spacing": "none",
        "contents": [
          {
            "type": "button",
            "style": "primary",
            "action": {
              "type": "message",
              "label": "查看介紹",
              "text": "法式麵包介紹"
            },
            "height": "md"
          }
        ],
        "margin": "none"
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "url": "https://i.imgur.com/lZjr9Ai.jpg"
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "sm",
        "contents": [
          {
            "type": "text",
            "text": "牛肉河粉",
            "wrap": True,
            "weight": "bold",
            "size": "4xl",
            "style": "normal",
            "decoration": "none",
            "align": "center",
            "gravity": "center",
            "offsetTop": "12.5%"
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "spacing": "none",
        "contents": [
          {
            "type": "button",
            "style": "primary",
            "action": {
              "type": "message",
              "label": "查看介紹",
              "text": "牛肉河粉介紹"
            },
            "height": "md"
          }
        ],
        "margin": "none"
      }
    }
  ]
})
    elif "介紹"in event.message.text:
        t=event.message.text.split('介紹')[0]
        if t=="生春捲":
            message=TextSendMessage(text='春捲之於越南餐有些像餃子之於中餐，幾乎是標誌性食品。在越南，春捲的種類和做法十分多樣，口味更是千變萬化。所以，吃越南菜時點一份春捲絕對是不二之選。其中一葉春捲和越南春捲都值得一試。前者以蔬菜為主，菜色鮮嫩，清新爽口；後者則是包裹著肉餡的，據說製作時，通過火候的變化可以去除油膩，基本保持了越南菜清淡自然的口味。')
        elif t=="法式麵包":
            message=TextSendMessage(text='越式法國麵包或稱越南式三明治或越南麵餅，是一種具東南亞色彩的法國麵包，雖然在國際上常被當成越南特色菜，但此食品廣泛流行於前中南半島等地區，在越南、柬埔寨、寮國均為日常食品，寮語稱為ເຂົ້າຈີ່，高棉語則稱為នំបុ័ង。製作該麵包時，除了用麵粉外，亦會加入米粉，質感相對較脆，也較傳統法國麵包為輕。')
        elif t=="牛肉河粉":
            message=TextSendMessage(text='越南粉，或稱河粉，是越南一種以大米製成的河粉。越南人常將這種河粉佐以生芽菜、香葉，並配上切片牛肉或雞絲食用，口感嫩滑且味道鮮美。與「麵餅」同被視為越南菜的代表菜色。現時在越南賣河粉的形式主要有兩類，有路邊攤和連鎖店兩種。')
    else:
         message = TextSendMessage(text=event.message.text)
    line_bot_api.reply_message(
        event.reply_token,message)


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/May/2021 21:28:04] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [22/May/2021 21:28:07] "POST /callback HTTP/1.1" 200 -
# 生春捲
# 法式麵包
# 127.0.0.1 - - [22/May/2021 21:28:13] "POST /callback HTTP/1.1" 200 -
# 127.0.0.1 - - [22/May/2021 21:28:17] "POST /callback HTTP/1.1" 200 -
# 牛肉河粉
